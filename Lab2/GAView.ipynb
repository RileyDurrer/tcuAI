# %%
import GAController
print(GAController.runGenerations())
# Out:
# Best of Each Generation:
# Gen 1: -3035398
# Gen 2: -2717415
# Gen 3: -1426392
# Gen 4: -869531
# Gen 5: -636382
# Gen 6: -350224
# Gen 7: -330907
# Gen 8: -195728
# Gen 9: -237710
# Gen 10: -75222
# Gen 11: -124421
# Gen 12: -50055
# Gen 13: -23072
# Gen 14: -16918
# Gen 15: -11133
# Gen 16: -9029
# Gen 17: -5214
# Gen 18: -3314
# Gen 19: -3288
# Gen 20: -5207
# Gen 21: -3359
# Gen 22: -2639
# Gen 23: -2777
# Gen 24: -2262
# Gen 25: -2660
# Gen 26: -2733
# Gen 27: -2323
# Gen 28: -2934
# Gen 29: -2540
# Gen 30: -3207
# Gen 31: -2341
# Gen 32: -2583
# Gen 33: -3048
# Gen 34: -2188
# Gen 35: -2403
# Gen 36: -3033
# Gen 37: -3300
# Gen 38: -1394
# Gen 39: -2116
# Gen 40: -3167
# Gen 41: -2684
# Gen 42: -2692
# Gen 43: -1734
# Gen 44: -1659
# Gen 45: -103
# Gen 46: -2526
# Gen 47: -1538
# Gen 48: -1988
# Gen 49: -1963
# Gen 50: -1426
# Gen 51: -1445
# Gen 52: -1848
# Gen 53: -1613
# Gen 54: -1878
# Gen 55: -1927
# Gen 56: -1682
# Gen 57: -1714
# Gen 58: -2169
# Gen 59: -2539
# ...
